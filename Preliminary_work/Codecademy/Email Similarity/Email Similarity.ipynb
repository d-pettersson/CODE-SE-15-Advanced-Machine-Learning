# %% [markdown]
# ## Email Similarity - implementing a Naives Bayes classifier on different datasets.

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
import plotly.graph_objects as go
import numpy as np

# %% [markdown]
# Download the dataset first

# %%
data = fetch_20newsgroups()

# %%
print(data.target_names)
# Out:
# ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space', 'soc.religion.christian', 'talk.politics.guns', 'talk.politics.mideast', 'talk.politics.misc', 'talk.religion.misc']

# %%
len(data.target_names)
# Out:
# 20

# %% [markdown]
# We want only the baseball and hockey categories

# %%
emails = fetch_20newsgroups(categories = ['rec.sport.baseball', 'rec.sport.hockey'])

# %% [markdown]
# Verifying that the categories are the correct ones

# %%
print(emails.target_names)
# Out:
# ['rec.sport.baseball', 'rec.sport.hockey']

# %% [markdown]
# Our interest in this dataset is to see how effective the NB Classifier is at telling the difference between a baseball email and a hockey email. Here's a random email out of our dataset.

# %%
print(emails.data[5])
# Out:
# From: mmb@lamar.ColoState.EDU (Michael Burger)
# Subject: More TV Info
# Distribution: na
# Nntp-Posting-Host: lamar.acns.colostate.edu
# Organization: Colorado State University, Fort Collins, CO  80523
# Lines: 36
#
# United States Coverage:
# Sunday April 18
#   N.J./N.Y.I. at Pittsburgh - 1:00 EDT to Eastern Time Zone
#   ABC - Gary Thorne and Bill Clement
#
#   St. Louis at Chicago - 12:00 CDT and 11:00 MDT - to Central/Mountain Zones
#   ABC - Mike Emerick and Jim Schoenfeld
#
#   Los Angeles at Calgary - 12:00 PDT and 11:00 ADT - to Pacific/Alaskan Zones
#   ABC - Al Michaels and John Davidson
#
# Tuesday, April 20
#   N.J./N.Y.I. at Pittsburgh - 7:30 EDT Nationwide
#   ESPN - Gary Thorne and Bill Clement
#
# Thursday, April 22 and Saturday April 24
#   To Be Announced - 7:30 EDT Nationwide
#   ESPN - To Be Announced
#
#
# Canadian Coverage:
#
# Sunday, April 18
#   Buffalo at Boston - 7:30 EDT Nationwide
#   TSN - ???
#
# Tuesday, April 20
#   N.J.D./N.Y. at Pittsburgh - 7:30 EDT Nationwide
#   TSN - ???
#
# Wednesday, April 21
#   St. Louis at Chicago - 8:30 EDT Nationwide
#   TSN - ???

# %%
print(emails.target[5])
# Out:
# 1

# %%
print(emails.target_names[1])
# Out:
# rec.sport.hockey

# %% [markdown]
# From the random email we extracted out of the dataset, we can conclude that it's a hockey related email

# %% [markdown]
# ## Creating the model

# %% [markdown]
# Splitting our data

# %%
train_emails = fetch_20newsgroups(categories = ['rec.sport.baseball', 'rec.sport.hockey'], subset='train', shuffle=True, random_state=108)

# %%
test_emails = fetch_20newsgroups(categories = ['rec.sport.baseball', 'rec.sport.hockey'], subset='test', shuffle=True, random_state=108)

# %% [markdown]
# We want to transform these emails into lists of word counts. We can use the CountVectorizer for that.

# %%
counter = CountVectorizer()

# %% [markdown]
# We need to tell counter what possible words can exist in our email.

# %%
counter.fit(test_emails.data + train_emails.data)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %% [markdown]
# From there, we can now make a list of the counts of the words in the training set.

# %%
train_counts = counter.transform(train_emails.data)

# %% [markdown]
# And do the same with the test set

# %%
test_counts = counter.transform(test_emails.data)

# %% [markdown]
# Time to create the NB Classifier!

# %%
classifier = MultinomialNB()

# %% [markdown]
# Fitting the classifier with our data and the labels associated with it

# %%
classifier.fit(train_counts, train_emails.target)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# Testing the classifier's score

# %%
classifier.score(test_counts, test_emails.target)
# Out:
# 0.9723618090452262

# %% [markdown]
# ## Testing different categories

# %%
def classifierTester(cat1, cat2):
    train_emails = fetch_20newsgroups(categories = [cat1, cat2], subset='train', shuffle=True, random_state=108)
    test_emails = fetch_20newsgroups(categories = [cat1, cat2], subset='test', shuffle=True, random_state=108)
    
    counter = CountVectorizer()
    counter.fit(test_emails.data + train_emails.data)
    
    train_counts = counter.transform(train_emails.data)
    test_counts = counter.transform(test_emails.data)
    
    classifier = MultinomialNB()
    classifier.fit(train_counts, train_emails.target)
    
    return classifier.score(test_counts, test_emails.target)

# %%
score_list = []

for first_cat in data.target_names:
    for second_cat in data.target_names:
        score_list.append(classifierTester(first_cat, second_cat))

# %%
print(score_list)
# Out:
# [1.0, 0.9788135593220338, 0.6886395511921458, 0.9915611814345991, 0.9914772727272727, 0.9943977591036415, 0.9887165021156559, 0.9916083916083916, 0.9902370990237099, 0.9874301675977654, 0.9874651810584958, 0.9874125874125874, 0.9901685393258427, 0.9734265734265735, 0.9775596072931276, 0.9651324965132496, 0.9853587115666179, 0.9482014388489208, 0.9570747217806042, 0.8491228070175438, 0.9788135593220338, 1.0, 0.5006385696040868, 0.939820742637644, 0.9431524547803618, 0.860969387755102, 0.975609756097561, 0.9796178343949045, 0.9860228716645489, 0.9847328244274809, 0.9961928934010152, 0.9643312101910828, 0.9232736572890026, 0.9668789808917198, 0.9719029374201787, 0.9796696315120712, 0.9827357237715804, 0.9816993464052287, 0.9814020028612304, 0.975, 0.6886395511921458, 0.5006385696040868, 1.0, 0.5, 0.4980744544287548, 0.5044359949302915, 0.5790816326530612, 0.589873417721519, 0.6136363636363636, 0.7155499367888748, 0.7919293820933165, 0.5822784810126582, 0.5349428208386277, 0.5962025316455696, 0.6104060913705583, 0.7361111111111112, 0.6503957783641161, 0.7480519480519481, 0.6420454545454546, 0.6589147286821705, 0.9915611814345991, 0.939820742637644, 0.5, 1.0, 0.8996138996138996, 0.9428208386277002, 0.9373401534526854, 0.983502538071066, 0.9974683544303797, 0.9961977186311787, 0.9974715549936789, 0.9746192893401016, 0.89171974522293, 0.9796954314720813, 0.9885496183206107, 0.9911392405063291, 0.9933862433862434, 0.98828125, 0.9928774928774928, 0.9906687402799378, 0.9914772727272727, 0.9431524547803618, 0.4980744544287548, 0.8996138996138996, 1.0, 0.9564102564102565, 0.9458064516129032, 0.9846350832266325, 0.9923371647509579, 0.989769820971867, 0.9961734693877551, 0.9667093469910372, 0.9215938303341902, 0.9667093469910372, 0.9884467265725289, 0.9923371647509579, 0.9893190921228304, 0.9829172141918529, 0.981294964028777, 0.9905660377358491, 0.9943977591036415, 0.860969387755102, 0.5044359949302915, 0.9428208386277002, 0.9564102564102565, 1.0, 0.9719745222929936, 0.9873577749683944, 0.987
# %% [markdown]
# ### Lowest scores categories pairs

# %%
low_scores = score_list[score_list<0.8]
low_scores_indices = np.nonzero(score_list<0.8)

# %%
def printScorePairs(indices):
    count = 0

    while count < len(indices[0]):
        for i in range(2):
            print(data.target_names[indices[i][count]])
            count += 1
        print('\n')

# %%
printScorePairs(low_scores_indices)
# Out:
# alt.atheism
# comp.os.ms-windows.misc
#
#
# comp.os.ms-windows.misc
# comp.graphics
#
#
# comp.os.ms-windows.misc
# comp.sys.mac.hardware
#
#
# comp.os.ms-windows.misc
# misc.forsale
#
#
# comp.os.ms-windows.misc
# rec.motorcycles
#
#
# comp.os.ms-windows.misc
# rec.sport.hockey
#
#
# comp.os.ms-windows.misc
# sci.electronics
#
#
# comp.os.ms-windows.misc
# sci.space
#
#
# comp.os.ms-windows.misc
# talk.politics.guns
#
#
# comp.os.ms-windows.misc
# talk.politics.misc
#
#
# comp.os.ms-windows.misc
# comp.os.ms-windows.misc
#
#
# comp.sys.mac.hardware
# comp.os.ms-windows.misc
#
#
# misc.forsale
# comp.os.ms-windows.misc
#
#
# rec.motorcycles
# comp.os.ms-windows.misc
#
#
# rec.sport.hockey
# comp.os.ms-windows.misc
#
#
# sci.electronics
# comp.os.ms-windows.misc
#
#
# sci.space
# comp.os.ms-windows.misc
#
#
# talk.politics.guns
# comp.os.ms-windows.misc
#
#
# talk.politics.misc
# comp.os.ms-windows.misc

# %% [markdown]
# ### Highest scores categories pairs

# %%
high_scores = np.where(np.logical_and(score_list>=0.8, score_list<1.0))
high_scores_indices = np.nonzero(np.logical_and(score_list>=0.8, score_list<1.0))

# %%
printScorePairs(high_scores_indices)
# Out:
# alt.atheism
# comp.sys.ibm.pc.hardware
#
#
# alt.atheism
# comp.windows.x
#
#
# alt.atheism
# rec.autos
#
#
# alt.atheism
# rec.sport.baseball
#
#
# alt.atheism
# sci.crypt
#
#
# alt.atheism
# sci.med
#
#
# alt.atheism
# soc.religion.christian
#
#
# alt.atheism
# talk.politics.mideast
#
#
# alt.atheism
# talk.religion.misc
#
#
# comp.graphics
# comp.sys.ibm.pc.hardware
#
#
# comp.graphics
# comp.windows.x
#
#
# comp.graphics
# rec.autos
#
#
# comp.graphics
# rec.sport.baseball
#
#
# comp.graphics
# sci.crypt
#
#
# comp.graphics
# sci.med
#
#
# comp.graphics
# soc.religion.christian
#
#
# comp.graphics
# talk.politics.mideast
#
#
# comp.graphics
# talk.religion.misc
#
#
# comp.sys.ibm.pc.hardware
# comp.graphics
#
#
# comp.sys.ibm.pc.hardware
# comp.windows.x
#
#
# comp.sys.ibm.pc.hardware
# rec.autos
#
#
# comp.sys.ibm.pc.hardware
# rec.sport.baseball
#
#
# comp.sys.ibm.pc.hardware
# sci.crypt
#
#
# comp.sys.ibm.pc.hardware
# sci.med
#
#
# comp.sys.ibm.pc.hardware
# soc.religion.christian
#
#
# comp.sys.ibm.pc.hardware
# talk.politics.mideast
#
#
# comp.sys.ibm.pc.hardware
# talk.religion.misc
#
#
# comp.sys.mac.hardware
# comp.graphics
#
#
# comp.sys.mac.hardware
# comp.windows.x
#
#
# comp.sys.mac.hardware
# rec.autos
#
#
# comp.sys.mac.hardware
# rec.sport.baseball
#
#
# comp.sys.mac.hardware
# sci.crypt
#
#
# comp.sys.mac.hardware
# sci.med
#
#
# comp.sys.mac.hardware
# soc.religion.christian
#
#
# comp.sys.mac.hardware
# talk.politics.mideast
#
#
# comp.sys.mac.hardware
# talk.religion.misc
#
#
# comp.windows.x
# comp.graphics
#
#
# comp.windows.x
# comp.sys.mac.hardware
#
#
# comp.windows.x
# rec.autos
#
#
# comp.windows.x
# rec.sport.baseball
#
#
# comp.windows.x
# sci.crypt
#
#
# comp.windows.x
# sci.med
#
#
# comp.windows.x
# soc.religion.christian
#
#
# comp.windows.x
# talk.politics.mideast
#
#
# comp.windows.x
# talk.religion.misc
#
#
# misc.forsale
# comp.graphics
#
#
# misc.forsale
# comp.sys.mac.hardware
#
#
# misc.forsale
# rec.autos
#
#
# misc.forsale
# rec.sport.baseball
#
#
# misc.forsale
# sci.crypt
#
#
# misc.forsale
# sci.med
#
#
# misc.forsale
# soc.religion.christian
#
#
# misc.forsale
# talk.politics.mideast
#
#
# misc.forsale
# talk.religion.misc
#
#
# rec.autos
# comp.graphics
#
#
# rec.autos
# comp.sys.mac.hardware
#
#
# rec.autos
# misc.forsale
#
#
# rec.autos
# rec.sport.baseball
#
#
# rec.autos
# sci.crypt
#
#
# rec.autos
# sci.med
#
#
# rec.autos
# soc.religion.christian
#
#
# rec.autos
# talk.politics.mideast
#
#
# rec.autos
# talk.religion.misc
#
#
# rec.motorcycles
# comp.graphics
#
#
# rec.motorcycles
# comp.sys.mac.hardware
#
#
# rec.motorcycles
# misc.forsale
#
#
# rec.motorcycles
# rec.sport.baseball
#
#
# rec.motorcycles
# sci.crypt
#
#
# rec.motorcycles
# sci.med
#
#
# rec.motorcycles
# soc.religion.christian
#
#
# rec.motorcycles
# talk.politics.mideast
#
#
# rec.motorcycles
# talk.religion.misc
#
#
# rec.sport.baseball
# comp.graphics
#
#
# rec.sport.baseball
# comp.sys.mac.hardware
#
#
# rec.sport.baseball
# misc.forsale
#
#
# rec.sport.baseball
# rec.motorcycles
#
#
# rec.sport.baseball
# sci.crypt
#
#
# rec.sport.baseball
# sci.med
#
#
# rec.sport.baseball
# soc.religion.christian
#
#
# rec.sport.baseball
# talk.politics.mideast
#
#
# rec.sport.baseball
# talk.religion.misc
#
#
# rec.sport.hockey
# comp.graphics
#
#
# rec.sport.hockey
# comp.sys.mac.hardware
#
#
# rec.sport.hockey
# misc.forsale
#
#
# rec.sport.hockey
# rec.motorcycles
#
#
# rec.sport.hockey
# sci.crypt
#
#
# rec.sport.hockey
# sci.med
#
#
# rec.sport.hockey
# soc.religion.christian
#
#
# rec.sport.hockey
# talk.politics.mideast
#
#
# rec.sport.hockey
# talk.religion.misc
#
#
# sci.crypt
# comp.graphics
#
#
# sci.crypt
# comp.sys.mac.hardware
#
#
# sci.crypt
# misc.forsale
#
#
# sci.crypt
# rec.motorcycles
#
#
# sci.crypt
# rec.sport.hockey
#
#
# sci.crypt
# sci.med
#
#
# sci.crypt
# soc.religion.christian
#
#
# sci.crypt
# talk.politics.mideast
#
#
# sci.crypt
# talk.religion.misc
#
#
# sci.electronics
# comp.graphics
#
#
# sci.electronics
# comp.sys.mac.hardware
#
#
# sci.electronics
# misc.forsale
#
#
# sci.electronics
# rec.motorcycles
#
#
# sci.electronics
# rec.sport.hockey
#
#
# sci.electronics
# sci.med
#
#
# sci.electronics
# soc.religion.christian
#
#
# sci.electronics
# talk.politics.mideast
#
#
# sci.electronics
# talk.religion.misc
#
#
# sci.med
# comp.graphics
#
#
# sci.med
# comp.sys.mac.hardware
#
#
# sci.med
# misc.forsale
#
#
# sci.med
# rec.motorcycles
#
#
# sci.med
# rec.sport.hockey
#
#
# sci.med
# sci.electronics
#
#
# sci.med
# soc.religion.christian
#
#
# sci.med
# talk.politics.mideast
#
#
# sci.med
# talk.religion.misc
#
#
# sci.space
# comp.graphics
#
#
# sci.space
# comp.sys.mac.hardware
#
#
# sci.space
# misc.forsale
#
#
# sci.space
# rec.motorcycles
#
#
# sci.space
# rec.sport.hockey
#
#
# sci.space
# sci.electronics
#
#
# sci.space
# soc.religion.christian
#
#
# sci.space
# talk.politics.mideast
#
#
# sci.space
# talk.religion.misc
#
#
# soc.religion.christian
# comp.graphics
#
#
# soc.religion.christian
# comp.sys.mac.hardware
#
#
# soc.religion.christian
# misc.forsale
#
#
# soc.religion.christian
# rec.motorcycles
#
#
# soc.religion.christian
# rec.sport.hockey
#
#
# soc.religion.christian
# sci.electronics
#
#
# soc.religion.christian
# sci.space
#
#
# soc.religion.christian
# talk.politics.mideast
#
#
# soc.religion.christian
# talk.religion.misc
#
#
# talk.politics.guns
# comp.graphics
#
#
# talk.politics.guns
# comp.sys.mac.hardware
#
#
# talk.politics.guns
# misc.forsale
#
#
# talk.politics.guns
# rec.motorcycles
#
#
# talk.politics.guns
# rec.sport.hockey
#
#
# talk.politics.guns
# sci.electronics
#
#
# talk.politics.guns
# sci.space
#
#
# talk.politics.guns
# talk.politics.mideast
#
#
# talk.politics.guns
# talk.religion.misc
#
#
# talk.politics.mideast
# comp.graphics
#
#
# talk.politics.mideast
# comp.sys.mac.hardware
#
#
# talk.politics.mideast
# misc.forsale
#
#
# talk.politics.mideast
# rec.motorcycles
#
#
# talk.politics.mideast
# rec.sport.hockey
#
#
# talk.politics.mideast
# sci.electronics
#
#
# talk.politics.mideast
# sci.space
#
#
# talk.politics.mideast
# talk.politics.guns
#
#
# talk.politics.mideast
# talk.religion.misc
#
#
# talk.politics.misc
# comp.graphics
#
#
# talk.politics.misc
# comp.sys.mac.hardware
#
#
# talk.politics.misc
# misc.forsale
#
#
# talk.politics.misc
# rec.motorcycles
#
#
# talk.politics.misc
# rec.sport.hockey
#
#
# talk.politics.misc
# sci.electronics
#
#
# talk.politics.misc
# sci.space
#
#
# talk.politics.misc
# talk.politics.guns
#
#
# talk.politics.misc
# talk.religion.misc
#
#
# talk.religion.misc
# comp.graphics
#
#
# talk.religion.misc
# comp.sys.mac.hardware
#
#
# talk.religion.misc
# misc.forsale
#
#
# talk.religion.misc
# rec.motorcycles
#
#
# talk.religion.misc
# rec.sport.hockey
#
#
# talk.religion.misc
# sci.electronics
#
#
# talk.religion.misc
# sci.space
#
#
# talk.religion.misc
# talk.politics.guns
#
#
# talk.religion.misc
# talk.politics.misc
